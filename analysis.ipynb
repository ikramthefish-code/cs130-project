# %%
import pandas as pd
import matplotlib.pyplot as plt 
food = pd.read_csv("~/Downloads/Classes/Sophomore Year/Spring/Cs 130/Project/cs130-project/food.csv")
food.Category
# Out:
# 0                                           Milk
# 1                                           Milk
# 2                                           Milk
# 3                                           Milk
# 4                                           Milk
#                           ...
# 7078            Tomatoes as ingredient in omelet
# 7079    Other vegetables as ingredient in omelet
# 7080           Vegetables as ingredient in curry
# 7081           Sauce as ingredient in hamburgers
# 7082        Industrial oil as ingredient in food
# Name: Category, Length: 7083, dtype: object

# %%
import pandas as pd
food = pd.read_csv("~/Downloads/Classes/Sophomore Year/Spring/Cs 130/Project/cs130-project/food.csv")
food.sort_values(by ="DataFiber", ascending = False).head()
# Out:
#                                                Category  \
# 4214                   Cereal (General Mills Fiber One)
# 4314                                         Wheat bran
# 7014  Nutritional powder mix (Kellogg's Special K20 ...
# 368                                        Cocoa powder
# 4181                        Cereal (Kellogg's All-Bran)
#
#                                             Description  \
# 4214                   Cereal (General Mills Fiber One)
# 4314                            Wheat bran, unprocessed
# 7014  Nutritional powder mix (Kellogg's Special K20 ...
# 368                     Cocoa powder, not reconstituted
# 4181                        Cereal (Kellogg's All-Bran)
#
#       Nutrient Data Bank Number  DataAlpha Carotene  Data.Beta Carotene  \
# 4214                   57206700                   5                   9
# 4314                   57601100                   0                   6
# 7014                   95201700                   0                   0
# 368                    11830150                   0                   0
# 4181                   57101000                   0                   4
#
#       DataBeta Cryptoxanthin  DataCarbohydrate  DataCholesterol  DataCholine  \
# 4214                       0             84.30                0         12.3
# 4314                       0             64.51                0         74.4
# 7014                       0             58.40                4         76.7
# 368                        0             57.90                0         12.0
# 4181                       0             74.24                0         49.4
#
#       DataFiber  ...  DataMajor MineralsPhosphorus  \
# 4214       46.2  ...                           200
# 4314       42.8  ...                          1013
# 7014       37.5  ...                            69
# 368        37.0  ...                           734
# 4181       29.3  ...                          1150
#
#       DataMajor MineralsPotassium  DataMajor MineralsSodium  \
# 4214                          374                       356
# 4314                         1182                         2
# 7014                          490                       280
# 368                          1524                        21
# 4181                         1020                       258
#
#       DataMajor MineralsZinc  DataVitaminsVitamin A - RAE  \
# 4214                   12.50                            1
# 4314                    7.27                            0
# 7014                    0.00                            2
# 368                     6.81                            0
# 4181                   12.40                          522
#
#       DataVitaminsVitamin B12  DataVitaminsVitamin B6  DataVitaminsVitamin C  \
# 4214                      5.0                   1.660                   20.0
# 4314                      0.0                   1.303                    0.0
# 7014                      8.3                   2.800                    0.0
# 368                       0.0                   0.118                    0.0
# 4181                     18.8                  12.000                   20.0
#
#       DataVitaminsVitamin E  DataVitaminsVitamin K
# 4214                   0.30                    0.6
# 4314                   1.49                    1.9
# 7014                   0.00                    0.0
# 368                    0.10                    2.5
# 4181                   1.19                    5.2
#
# [5 rows x 38 columns]

# %%
food.
