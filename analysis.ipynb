# %%
#import pandas as pd
#import matplotlib.pyplot as plt 
#food = pd.read_csv("~/Downloads/Classes/Sophomore Year/Spring/Cs 130/Project/cs130-project/food.csv")
#food.Category

# %%
#import pandas as pd
#food = pd.read_csv("~/Downloads/Classes/Sophomore Year/Spring/Cs 130/Project/cs130-project/food.csv")
#food.sort_values(by ="Fiber", ascending = False).head()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
food = pd.read_csv("food.csv")
#making a function that looks at all of the dairy 
food.head()
# Out:
#    Category(2)             Description  Nutrient Data Bank Number  \
# 0         Milk             Milk, whole                   11111000
# 1   Buttermilk       Buttermilk, whole                   11115300
# 2  Goat's milk      Goat's milk, whole                   11116000
# 3     Soy milk                Soy milk                   11320000
# 4  Almond milk  Almond milk, sweetened                   11350000
#
#    Alpha Carotene  Beta Carotene  Beta Cryptoxanthin  Carbohydrate  \
# 0               0              7                   0          4.67
# 1               0              7                   0          4.88
# 2               0              7                   0          4.45
# 3               0              2                   0          4.92
# 4               0              0                   0          5.24
#
#    Cholesterol  Choline  Fiber  ...  Major MineralsPhosphorus  \
# 0           12     17.8    0.0  ...                       101
# 1           11     14.6    0.0  ...                        85
# 2           11     16.0    0.0  ...                       111
# 3            0     23.6    0.2  ...                        43
# 4            0      3.0    0.2  ...                         9
#
#    Major MineralsPotassium  Major MineralsSodium  Major MineralsZinc  \
# 0                      150                    38                0.41
# 1                      135                   105                0.38
# 2                      204                    50                0.30
# 3                      122                    47                0.26
# 4                       64                    69                0.06
#
#    VitaminsVitamin A - RAE  VitaminsVitamin B12  VitaminsVitamin B6  \
# 0                       32                 0.54               0.061
# 1                       47                 0.46               0.036
# 2                       57                 0.07               0.046
# 3                       55                 0.85               0.031
# 4                       86                 0.00               0.000
#
#    VitaminsVitamin C  VitaminsVitamin E  VitaminsVitamin K
# 0                0.0               0.05                0.3
# 1                0.0               0.07                0.3
# 2                1.3               0.07                0.3
# 3                0.0               0.11                3.0
# 4                0.0               2.70                0.0
#
# [5 rows x 38 columns]

# %%
#food.info()

# %%
#food.describe()

# %%
food.columns
# Out:
# Index(['Category(2)', 'Description', 'Nutrient Data Bank Number',
#        'Alpha Carotene', 'Beta Carotene', 'Beta Cryptoxanthin', 'Carbohydrate',
#        'Cholesterol', 'Choline', 'Fiber', 'Lutein and Zeaxanthin', 'Lycopene',
#        'Niacin', 'Protein', 'Retinol', 'Riboflavin', 'Selenium', 'Sugar Total',
#        'Thiamin', 'Water', 'FatMonosaturated Fat', 'FatPolysaturated Fat',
#        'FatSaturated Fat', 'FatTotal Lipid', 'Major MineralsCalcium',
#        'Major MineralsCopper', 'Major MineralsIron', 'Major MineralsMagnesium',
#        'Major MineralsPhosphorus', 'Major MineralsPotassium',
#        'Major MineralsSodium', 'Major MineralsZinc', 'VitaminsVitamin A - RAE',
#        'VitaminsVitamin B12', 'VitaminsVitamin B6', 'VitaminsVitamin C',
#        'VitaminsVitamin E', 'VitaminsVitamin K'],
#       dtype='object')

# %%
food.index
# Out:
# RangeIndex(start=0, stop=1671, step=1)

# %%
#Using this as a reference for later for coloums 
food[["Category(2)", "Description"]]
# Out:
#                                    Category(2)  \
# 0                                         Milk
# 1                                   Buttermilk
# 2                                  Goat's milk
# 3                                     Soy milk
# 4                                  Almond milk
# ...                                        ...
# 1666          Tomatoes as ingredient in omelet
# 1667  Other vegetables as ingredient in omelet
# 1668         Vegetables as ingredient in curry
# 1669         Sauce as ingredient in hamburgers
# 1670      Industrial oil as ingredient in food
#
#                                    Description
# 0                                  Milk, whole
# 1                            Buttermilk, whole
# 2                           Goat's milk, whole
# 3                                     Soy milk
# 4                       Almond milk, sweetened
# ...                                        ...
# 1666          Tomatoes as ingredient in omelet
# 1667  Other vegetables as ingredient in omelet
# 1668         Vegetables as ingredient in curry
# 1669         Sauce as ingredient in hamburgers
# 1670      Industrial oil as ingredient in food
#
# [1671 rows x 2 columns]

# %%
food.head()
# Out:
#    Category(2)             Description  Nutrient Data Bank Number  \
# 0         Milk             Milk, whole                   11111000
# 1   Buttermilk       Buttermilk, whole                   11115300
# 2  Goat's milk      Goat's milk, whole                   11116000
# 3     Soy milk                Soy milk                   11320000
# 4  Almond milk  Almond milk, sweetened                   11350000
#
#    Alpha Carotene  Beta Carotene  Beta Cryptoxanthin  Carbohydrate  \
# 0               0              7                   0          4.67
# 1               0              7                   0          4.88
# 2               0              7                   0          4.45
# 3               0              2                   0          4.92
# 4               0              0                   0          5.24
#
#    Cholesterol  Choline  Fiber  ...  Major MineralsPhosphorus  \
# 0           12     17.8    0.0  ...                       101
# 1           11     14.6    0.0  ...                        85
# 2           11     16.0    0.0  ...                       111
# 3            0     23.6    0.2  ...                        43
# 4            0      3.0    0.2  ...                         9
#
#    Major MineralsPotassium  Major MineralsSodium  Major MineralsZinc  \
# 0                      150                    38                0.41
# 1                      135                   105                0.38
# 2                      204                    50                0.30
# 3                      122                    47                0.26
# 4                       64                    69                0.06
#
#    VitaminsVitamin A - RAE  VitaminsVitamin B12  VitaminsVitamin B6  \
# 0                       32                 0.54               0.061
# 1                       47                 0.46               0.036
# 2                       57                 0.07               0.046
# 3                       55                 0.85               0.031
# 4                       86                 0.00               0.000
#
#    VitaminsVitamin C  VitaminsVitamin E  VitaminsVitamin K
# 0                0.0               0.05                0.3
# 1                0.0               0.07                0.3
# 2                1.3               0.07                0.3
# 3                0.0               0.11                3.0
# 4                0.0               2.70                0.0
#
# [5 rows x 38 columns]

# %%
#testing for row checking
food.iloc[0]["Category(2)"]
# Out:
# 'Milk'

# %%
#making a function that looks at all of the dairy 
def milk():
    return food[(food["Category(2)"].str.contains("Milk"))| food["Category(2)"].str.contains("milk") |  food["Category(2)"].str.contains("Cheese") | food["Category(2)"].str.contains("Yogurt") | (food["Description"].str.contains("milk")) & (food["Category(2)"] != "Grits") & (food["Category(2)"] != "Rice") & (food["Category(2)"] != "Oatmeal") ]
milk()
# Out:
#     Category(2)             Description  Nutrient Data Bank Number  \
# 0          Milk             Milk, whole                   11111000
# 1    Buttermilk       Buttermilk, whole                   11115300
# 2   Goat's milk      Goat's milk, whole                   11116000
# 3      Soy milk                Soy milk                   11320000
# 4   Almond milk  Almond milk, sweetened                   11350000
# 5     Rice milk               Rice milk                   11360000
# 6  Coconut milk            Coconut milk                   11370000
# 7        Yogurt             Yogurt, NFS                   11400000
# 8        Cheese             Cheese, NFS                   14010000
#
#    Alpha Carotene  Beta Carotene  Beta Cryptoxanthin  Carbohydrate  \
# 0               0              7                   0          4.67
# 1               0              7                   0          4.88
# 2               0              7                   0          4.45
# 3               0              2                   0          4.92
# 4               0              0                   0          5.24
# 5               0              0                   0          9.17
# 6               0              0                   0          2.92
# 7               0              2                   0          7.04
# 8               0             99                   9          5.00
#
#    Cholesterol  Choline  Fiber  ...  Major MineralsPhosphorus  \
# 0           12     17.8    0.0  ...                       101
# 1           11     14.6    0.0  ...                        85
# 2           11     16.0    0.0  ...                       111
# 3            0     23.6    0.2  ...                        43
# 4            0      3.0    0.2  ...                         9
# 5            0      2.1    0.3  ...                        56
# 6            0      0.0    0.0  ...                         0
# 7            6     15.2    0.0  ...                       144
# 8           91     24.2    0.0  ...                       582
#
#    Major MineralsPotassium  Major MineralsSodium  Major MineralsZinc  \
# 0                      150                    38                0.41
# 1                      135                   105                0.38
# 2                      204                    50                0.30
# 3                      122                    47                0.26
# 4                       64                    69                0.06
# 5                       27                    39                0.13
# 6                       19                    19                0.00
# 7                      234                    70                0.89
# 8                      164                   904                3.09
#
#    VitaminsVitamin A - RAE  VitaminsVitamin B12  VitaminsVitamin B6  \
# 0                       32                 0.54               0.061
# 1                       47                 0.46               0.036
# 2                       57                 0.07               0.046
# 3                       55                 0.85               0.031
# 4                       86                 0.00               0.000
# 5                       63                 0.63               0.039
# 6                       63                 0.63               0.000
# 7                       14                 0.56               0.049
# 8                      298                 1.24               0.091
#
#    VitaminsVitamin C  VitaminsVitamin E  VitaminsVitamin K
# 0                0.0               0.05                0.3
# 1                0.0               0.07                0.3
# 2                1.3               0.07                0.3
# 3                0.0               0.11                3.0
# 4                0.0               2.70                0.0
# 5                0.0               0.47                0.2
# 6                0.0               0.00                0.0
# 7                0.8               0.03                0.2
# 8                0.0               0.79                2.7
#
# [9 rows x 38 columns]

# %%
#making a Function looking for meats
